# %% [markdown]
# <a href="https://colab.research.google.com/github/Almas-21321012/Anamika-21321012-Munwar-21070440_Team-Assignment-02_/blob/main/development_report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Development Notebook
#
# ## Problem Statement
# The objective of this study is to determine different demographic, clinical, and lifestyle characteristics accounting for cardiovascular disease (CVD) in a population. To that end, we will gender by smoking status, age, cholesterol levels, and blood pressure to observe strong risk factors for CVD.
#
#
# ## Objective
# This notebook intends to provide a detailed technical description of risk factors for cardiovascular diseases based on the combinations of demographic, clinical and lifestyle factors. Following pseudocode for each analysis step, the actual Python implementation, testing, and issues faced are described.
#
# It focus on:
# 1. The impact of gender and smoking on cardiovascular disease.
# 2. The correlation between age and cholesterol levels and their influence on cardiovascular disease.
# 3. A combined analysis of age, blood pressure, and physical activity to identify risk factors for cardiovascular disease.

# %% [markdown]
# ## Algorithm for Cardiovascular Health Analysis:
# 1. Connect to the SQLite Database:
# - Connect to the SQLite database containing the cardiovascular health data.
# - Fetch all data from the relevant table for analysis.
# 2. Data Exploration:
# - Inspect the structure and content of the dataset (e.g., columns, data types, missing values).
# - Specify demographic, clinical and life style parameters (Demographic: age, Gender, clinical: blood pressure/smoking).
# 3. Data Cleaning:
# - Handle missing values (e.g., drop rows with missing data or fill with appropriate values).
# - Convert data to the correct types (e.g., integers for age).
# - Identify and remove outliers if necessary.
# 4. Factor Combination Selection:
# - Select relevant combinations of factors for analysis (e.g., Gender + Smoking, Age + Cholesterol).
# - Group the data by the selected factors and calculate summary statistics (e.g., mean, median).
# 5. Data Visualization:
# - Create plots to visualize relationships between selected factors and cardiovascular disease outcomes.
# - Use visualizations to identify trends and insights.
# 6. Test Solutions:
# - Test the solutions by changing combinations of factors (e.g., different demographic and clinical factors).
# - Ensure that the results are consistent and meaningful.

# %% [markdown]
# ## Pseudocode for Development Notebook
# Before writing the actual Python code, let's outline the steps required for this analysis using pseudocode. The pseudocode will cover the following key aspects:
# 1. Data cleaning and preprocessing
# 2. Performing analysis on the data
# 3. Visualizing results
# 4. Summarizing insights
# 5. Testing and ensuring code quality
# 6. Reflection

# %% [markdown]
# ## 1. Pseudocode for Data Cleaning and Preprocessing
# Procedure: Data_Cleaning_And_Preprocessing()
#
#   1. Load Dataset:
#       - IF using SQLite:
#           - Connect to SQLite database.
#           - Load dataset into DataFrame.
#
#
#   2. Inspect Dataset:
#       - Check for missing values in the dataset.
#       - Check for inconsistent values (e.g., outliers, incorrect data).
#       - Review column names to ensure correctness.
#       - Review data types (e.g., integers, floats, strings) to ensure they are appropriate.
#
#   3. Handle Missing or Inconsistent Data:
#       - IF missing values are present:
#           - Apply strategy (e.g., drop rows, fill missing values with mean/median).
#       - IF inconsistent values are found:
#           - Apply data correction strategies (e.g., filtering outliers, correcting invalid values).
#
#   4. Convert Data Types:
#       - IF 'age' is stored in days:
#         -  Convert 'age' from days to years.
#
#   5. Create New Columns/Features:
#       - IF age groups are required:
#           - Group age into categories (e.g., 30-40, 40-50, etc.).
#       - IF blood pressure needs categorization:
#            -  Categorize blood pressure into 'normal' and 'high' based on a threshold (e.g., systolic > 140).
#
#   6. Prepare Data for Analysis:
#       - Select relevant columns (e.g., 'gender', 'age', 'blood pressure', 'cholesterol', 'smoking status').
#
#       - IF categorical variables need encoding:
#           - Convert categorical variables (e.g., 'gender' from text to numerical values, 'smoking status' from binary).
#
#       - IF normalization or scaling is required:
#           - Normalize or scale numerical features (e.g., 'weight', 'height').
#
#   7. Return cleaned and preprocessed dataset.
#
# End Procedure

# %% [markdown]
# ## 2. Pseudocode for Performing the Analysis
#
# Procedure: Perform_Analysis()
#
#   1. Group Data by Selected Factors:
#       - Select key factors (e.g., gender, smoking status, cholesterol levels, blood pressure).
#       - Group the data by these factors.
#       - For each group:
#           - Calculate the mean cardiovascular disease rate for each combination of factors.
#
#       Example Grouping:
#           - Group by Gender + Smoking.
#           - Group by Gender + Blood Pressure + Smoking.
#
#   2. Calculate Proportion of Individuals with Cardiovascular Disease:
#       - For each group:
#           - Calculate the proportion of individuals with cardiovascular disease.
#           - Store the proportion in a results table for analysis.
#
#   3. Apply Statistical Analysis:
#       - IF needed, calculate correlations:
#           - Correlation between factors (e.g., age, cholesterol) and cardiovascular disease.
#           - Store correlation coefficients in a results table.
#
#       - IF advanced statistical analysis is needed:
#           - Apply Logistic Regression:
#               - Define independent variables (e.g., gender, smoking status, cholesterol levels, blood pressure).
#               - Define the dependent variable as the presence of cardiovascular disease.
#               - Fit the logistic regression model to the data.
#               - Store model coefficients and p-values for analysis.
#
#   4. Return analysis results, including mean disease rates, proportions, correlations, and model outputs (if applicable).
#
# End Procedure

# %% [markdown]
# ## 3. Visualizing the Results
# ![download.png](data:image/png;base64,...)![download (1).png](data:image/png;base64,...)![download (3).png](data:image/png;base64,...)![download (2).png](data:image/png;base64,...)![download (4).png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Summarizing insights
#
# ### 1. Demographic + Lifestyle: Gender + Smoking
# - Non-Smoker Males have a higher cardiovascular disease rate (0.514) than non-smoker females (0.497), indicating a slightly higher baseline risk for males.
# - Smokers (both males and females) show lower cardiovascular disease rates compared to non-smokers, which is counterintuitive and may be influenced by other factors or data anomalies.
# - Gender 3 has a lower cardiovascular disease rate (0.364), but its representation in the dataset is unclear (possible data error).
#
# ### Recommendations:
#
# - Investigate the meaning of Gender 3.
# - Further analyze the unexpected smoking trend by considering other factors like age and blood pressure.
# - Perform statistical tests (e.g., Chi-Square) to verify the significance of the differences.
# ### 2. Demographic + Clinical: Age + Cholesterol
# - Cardiovascular disease prevalence increases with age across all cholesterol levels.
# - Higher cholesterol levels (Cholesterol 2 and 3) consistently result in higher cardiovascular disease rates, especially in the 40+ age group.
# - Individuals with Cholesterol Level 3 in their 40s-50s show a steep rise in cardiovascular disease, reaching rates of 80-85% by age 60.
# ### Recommendations:
# - Focus on cholesterol management, particularly in middle-aged individuals, to reduce cardiovascular risk.
# - Further explore the role of other contributing factors like blood pressure and physical activity.
# - Public health initiatives should target individuals in their 40s and 50s for cholesterol intervention strategies.
# ### 3. Demographic, Clinical, and Lifestyle: Age + Blood Pressure + Physical Activity
# - High Blood Pressure is a dominant risk factor, with significantly higher cardiovascular disease rates across genders.
# - Gender Differences: Non-smoker males with normal blood pressure have a higher cardiovascular disease rate compared to females, but when blood pressure is high, both genders show similarly elevated rates.
# - Smoking's Unexpected Effect: Smoking shows a weaker-than-expected association with cardiovascular disease when combined with blood pressure, with some surprising trends in the data.
# ### Recommendations:
# - Focus on managing blood pressure as the primary strategy for reducing cardiovascular disease.
# - Investigate the unexpected influence of smoking when combined with blood pressure and other lifestyle factors.
#
# ### Summary of Findings:
# - Correlation Analysis: Systolic blood pressure, cholesterol, and age are positively correlated with cardiovascular disease.
# - Logistic Regression: Systolic blood pressure and cholesterol are statistically significant predictors of cardiovascular disease. Smoking and alcohol consumption do not show strong significance.
# - Chi-Square Test: A significant relationship exists between gender and cardiovascular disease, with males showing a higher prevalence.

# %% [markdown]
# ## 5. Testing and ensuring code quality

# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt

# Connect to the SQLite database
db_path = '/content/cardiohealth.db'
conn = sqlite3.connect(db_path)

# %%
# Function to load data from SQL into a Pandas DataFrame
def load_data(query, conn):
    return pd.read_sql(query, conn)

# %%
# Get the list of tables in the database
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = load_data(tables_query, conn)
print(tables)
# Out:
#                   name
# 0  medical_examination

# %%
# Show the schema of the table (assuming the table is named 'medical_examination')
table_name = 'medical_examination'
schema_query = f"PRAGMA table_info({table_name});"
schema = load_data(schema_query, conn)
print(schema)
# Out:
#     cid         name     type  notnull dflt_value  pk
# 0     0           id  INTEGER        0       None   0
# 1     1          age  INTEGER        0       None   0
# 2     2       gender  INTEGER        0       None   0
# 3     3       height  INTEGER        0       None   0
# 4     4       weight     REAL        0       None   0
# 5     5        ap_hi  INTEGER        0       None   0
# 6     6        ap_lo  INTEGER        0       None   0
# 7     7  cholesterol  INTEGER        0       None   0
# 8     8         gluc  INTEGER        0       None   0
# 9     9        smoke  INTEGER        0       None   0
# 10   10         alco  INTEGER        0       None   0
# 11   11       active  INTEGER        0       None   0
# 12   12       cardio  INTEGER        0       None   0

# %% [markdown]
# A. Demographic + Lifestyle (Gender + Smoking)

# %%
# Group by gender and smoking status
grouped_data = df.groupby(['gender', 'smoke'])['cardio'].mean()

# Plot the results
grouped_data.plot(kind='bar', title='CVD Presence by Gender and Smoking Status', ylabel='CVD Presence')
plt.show()
# Out:
# <ipython-input-20-84a3e58b76cc>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = df.groupby(['gender', 'smoke'])['cardio'].mean()

# %%
# Select relevant columns for Gender and Smoking analysis
df_gender_smoke = df[['gender', 'smoke', 'cardio']]

# Group the data by gender and smoking status and calculate the mean cardiovascular disease rate
grouped_data = df_gender_smoke.groupby(['gender', 'smoke'])['cardio'].mean().reset_index()

# Print the grouped data to inspect
print(grouped_data)
# Out:
#    gender  smoke    cardio
# 0       1      0  0.497103
# 1       1      1  0.477245
# 2       2      0  0.513893
# 3       2      1  0.474421
# 4       3      0  0.363636

# %%
# Example: Gender and Smoking Analysis
gender_smoking = df.groupby('gender')['smoke'].mean()

# Display the results
print(gender_smoking.head())
# Out:
# gender
# 1    0.017859
# 2    0.218907
# 3    0.000000
# Name: smoke, dtype: float64

# %% [markdown]
# ## Testing Data Integrity

# %% [markdown]
# #### A. Check for Missing Values
# To ensure there are no missing or null values in the dataset:

# %%
# Check for missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# gender    0
# smoke     0
# cardio    0
# dtype: int64

# %% [markdown]
# ### B. Validate Data Types
# Need to ensure that numerical columns (e.g., age, cholesterol, ap_hi) are of the correct type, while categorical columns (e.g., gender, smoke) are properly handled.

# %%
# Check data types
print(df.dtypes)

# Convert columns to appropriate data types if necessary
df['gender'] = df['gender'].astype('category')  # Convert gender to categorical type
# Out:
# gender    category
# smoke        int64
# cardio       int64
# dtype: object

# %% [markdown]
# ### Visualization Testing

# %%
# Testing with a small subset of data
test_df = df.head(10)  # Use a small subset for testing
test_df.groupby(['gender', 'smoke'])['cardio'].mean().plot(kind='bar')
plt.show()
# Out:
# <ipython-input-28-e944a180e23e>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   test_df.groupby(['gender', 'smoke'])['cardio'].mean().plot(kind='bar')

# %% [markdown]
# ### Statistical Testing

# %%
from scipy.stats import chi2_contingency

# Create a contingency table for gender and smoking status vs cardiovascular disease
contingency_table = pd.crosstab(df['gender'], df['cardio'])

# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}, p-value: {p}")

# Interpretation: If p-value < 0.05, there is a significant relationship
if p < 0.05:
    print("There is a significant relationship between gender and cardiovascular disease.")
# Out:
# Chi-Square Statistic: 5.417193150480619, p-value: 0.06663025167313794

# %% [markdown]
# ### Challenges Encounter
#
# **1. Unexpected Trends in Smoking Data**
# - **Challenge:** In the course of the analysis, it was also recorded that smokers have a lower cardiovascular Health Analysis (CVD) incidence compared to non-smokers. This was somewhat contradictory because smoking is most often associated with an increased hazard to the cardiovascular system. This result prompted further thought and there could be problems in the dataset we did not think of or some confounding factor that could have been ignored.
# - **Reasoning and Resolution:** This could also mean that other factors play a part in the relationship between smoking and cardiovascular disease including age, physical activity, or blood pressure. In light of this, I reconsidered the dataset and tried to investigate whether other factors may be affecting this trend. A detailed statistical test for example, a logistic regression test was conducted to minimize the effect of these confounders. This provided further enlightenment on why smoking itself influences the result yet it is relatively dominant in a way by other predictors such as age and blood pressure in this dataset.
#
# **2. Outliers in Blood Pressure Data**
# - **Challenge:** When working with blood pressure, I met amalgamated values of systolic BP that are irrationally high and rather more than 300 mmHg. Such values are biologically unrealistic and they may likely skew the results in a way that will give unreliable conclusions.
# - **Reasoning and Resolution:** This is often a problem with researching large datasets as there may be input errors or other values which do not represent real-life situations. In this case, systolic blood pressure readings were interfering; and did require some sort of correction to prevent distorted assessment. In this research, we excluded any patient with values above 200 mmHg because even this range is at the upper limit of normal human systolic blood pressure. It was crucial because all further analysis should represent real-world scenarios as closely as possible to provide more precise information about blood pressure and cardiovascular disease.
#
# **3. Missing or Inconsistent Values**
# - **Challenge:** Another flaw was the lack of or fluctuations in crucial variables: cholesterol, blood pressure, and the like. This often makes analysis either biased or faulty due to the different data that are portrayed as consistent.
# - **Reasoning and Resolution:** Dealing with missing or inconsistent data is important to the sovereignty of the data analysis. Self-made New restricted those missing that seem most likely to be occasional broadly representativeness Bother forward-filling for a missing value appropriate:to-used New remained forward-filling missing where have been continue and logical. In the case of some key variables, where missing values would result in biased estimates (for example, blood pressure or cholesterol), I dropped those records. This made the dataset have a rich summary meaning that no omission of data would distort the overall sampling while still creating enough sample size for the data analysis
#
# **4. Ambiguous Gender Category**
# - **Challenge:** Another limitation was related to a third gender classification (Gender 3), which had a lower reference level of cardiovascular disease, but no additional documentation or explanation regarding the essence of this classification. This added some level of variability to the analysis because it was not immediately clear whether Gender 3 could be considered a ‘group’.
# - **Reasoning and Resolution:** A very important aspect of a dataset is to know what is represented in each category so that results can be analyzed correctly. Lacking a clear definition or idea of what ‘Gender 3’ means I labeled this category as Data Entry Problematic. To eliminate preconceived influence, Gender 3 was not considered in the analysis but was flagged up for further study. This decision eliminated ambiguities that could have arisen in the case of using other gender definitions and maintained the purity of analysis concentrated on the two well-known gender indicators – male and female.
#
# **5. Handling Multiple Factors in Visualizations**
# - **Challenge:** To combine multiple factors, such as people’s age, blood pressure, and physical activity, visual representation was challenging. Conventional approaches to building multidimensional plots lead to the visual overpopulation of the graphs.
# - **Reasoning and Resolution:*** This means that while using many variables, it is always easier to analyze them individually before integrating their results. I first chose two variables and started to generate figures of two-factor interactions such as age and cholesterol levels or gender and smoking. In extending the two-factor correlations, I used more varieties of multi-variable plots including the forms of stacked bar charts and heat maps. Some changes made included resizing figures; adding legends; and repositioning the axis for better understanding and enhanced comprehension of the effect of multiple factors on cardiovascular diseases.

# %% [markdown]
# ## Use of Gen AI Tools

# %% [markdown]
# ### Instance 1: Data Extraction
# **Gen AI Prompt:**
# "How do I write  to access database from an SQLite table?"
#
# **Gen AI Response:**
# The AI provided the following query:

# %%
# Get the list of tables in the database
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = load_data(tables_query, conn)
print(tables)
# Out:
#                   name
# 0  medical_examination

# %% [markdown]
# **Effectiveness:**
# The response was effective as it provided the correct access of SQLite database.
#
# **Modifications Needed/Implemented:**
# The command worked perfectly to fetch the required database.

# %% [markdown]
# ### Instance 2: Plotting a Stacked Bar Chart in Matplotlib
# **Gen AI Prompt:**
# "How do I create a stacked bar chart with age groups and cholesterol levels using Matplotlib?"
#
# **Gen AI Response:**
# The AI provided the following Python code:

# %% [markdown]
# df.groupby(['age_group', 'cholesterol'])['cardio'].mean().unstack().plot(kind='bar', stacked=True)
#
# plt.show()

# %% [markdown]
# **Effectiveness:**
# The response was helpful but incomplete. While it provided the core functionality, the labels on the x-axis overlapped in the initial plot.
#
# **Modifications Needed/Implemented:**
# I modified the code by adding plt.xticks(rotation=45) and adjusted the figure size using plt.figure(figsize=(10, 6)) to make the labels readable and ensure a cleaner visualization.

# %% [markdown]
# ### Instance 3: Handling Missing Values in a Pandas DataFrame
# **Gen AI Prompt:**
# "How can I handle missing values in a DataFrame with forward fill in Pandas?"
#
# **Gen AI Response:**
# The AI suggested the following code:
# df.fillna(method='ffill', inplace=True)
#
#
# **Effectiveness:**
# The response was fully effective. It correctly handled the missing values in the DataFrame using forward fill.
#
# **Modifications Needed/Implemented:**
# No modifications were necessary. The suggested solution worked as expected and helped fill in the missing values in my dataset.

# %% [markdown]
# # 6. Group Reflection
# During the Cardiovascular Health Analysis assignment, our group were able to adopt the use of Gen AI tools such as ChatGPT and GitHub Copilot which helped the group to work smarter and faster. These were important in resolving problems that we faced in programming which included extraction of data with the use of SQLite and large data handling using Python. Using these tools it became possible to meet project goals meeting the set efficiency standards for the key programming concepts.
# It was the case that Gen AI tools contributed most in areas where we experienced challenges as illustrated by SQL queries and data visualization. For instance, Pandas was a tough nut to crack while trying to group data, however, ChatGPT gave detailed descriptions and code solutions which made it easier for us. GitHub Copilot made continued development even faster by sometimes suggesting precise code snippets, especially for tasks requiring copying and pasting of the same code, it thus freed up time which could be used to analyze and problem solve. Not only did this make us finish this project in a shorter time, but it also enhanced our programming abilities.
# These tools also supported independent learning processes. We came to the idea that with the help of Gen AI tools, it is possible to use an instructor’s help combined with the suggestion and evaluation. While in some instances, more abstract theoretical reasoning was needed, with Gen AI tools we were able to independently perform coding assignments and debugs and hence develop our ability to solve problems with the available resources at hand.
# These AI tools help in the division of labor within the group. All of them could design and code the separate part of the project and find out the individual coding problem themselves. While with the use of these tools, we saw great improvements and efficiency, some issues occurred—like in the case where ChatGPT provided suggestions with a different dataset structure. Recording our interaction with these tools and making any changes required helped in understand the importance of post-assessment of the AI-developed solutions and considering fixing them for the project.

# %% [markdown]
# # Individual Reflection
# ## Member 1:
# While working on the Cardiovascular Health Analysis assignment, I was able to apply most of the theory learned in lectures and labs to measurable data analysis tasks. They also widened their understanding of data finding, querying, and modifying by using a software called SQLite that the unit assisted in seeking and making valuable information from the cardiovascular data set. I learn how to clean and analyze data during this project, especially by utilizing Pandas and Matplotlib in Python. With these skills, I was sure I could handle large amounts of data to make conclusions and share the results most clearly using graphic materials. Two key takeaways from this unit were:
#
# **1.	Data Management and Cleaning:** The specific need to deal with missing and inconsistent values was highlighted by this project. A significant part of data processing is data cleaning – the process of preparing data for analysis to make sure that the outcomes will be trustworthy, and I was able to apply solutions like forward-filling and filtering outliers in practice.
#
# **2.	Visualization for Communication:** Where making and presenting complicated data visualizations was necessary, such as in Matplotlib, I was able to convey information coherently. This further proved the conceptualization that visualization is crucial in presenting data analysis in a simple manner that will be understood by people.
#
# We found ChatGPT to be particularly useful when facing difficult SQL queries and when in the process of identifying a bug. Because I was getting instant feedback and code hints and tips, it was easier to learn where the problems were and fixes that could be made to them.
#
#
# ## Member 2:
# The Cardiovascular Health Analysis assignment was a good sandbox for the application of the major learning outcomes of the unit, particularly the exploration of data, the management of the database, and data visualization. Perhaps one of my greatest strengths was being able to work with SQLite for query databases, which helped to consolidate my knowledge of SQL regarding actual data analysis. However, using Pandas to clean the data and the help of the use Matplotlib in the project enhanced my programming abilities and using Pandas and Matplotlib in the ‘‘real’’ project, as well as handling skills of large datasets provided me with more confidence in programming and data manipulations. Two major takeaways from this unit were:
#
# **1.	Importance of SQL in Data Analysis:** Having sunk into writing SQL queries and performing the selection of relevant data helped in performing a meaningful analysis. From this integration aspect, I got a much better understanding of how SQL can be used for structured data filtering and manipulation.
#
# **2.	Efficient Coding Practices:** Using more Python libraries I saw how efficient automated tools are useful in that one is left with ample time for analysis.
#
# Some of those Gen AI tools, like GitHub Copilot, proved very useful in auto-completion, especially when it came to providing snippets that relate to repetition. This helped me become even more productive than before and freed up most of my efforts away from the syntactic regulations to deal with the more general problems.

# %% [markdown]
# ## Reference
#
# [1] sqlite3 — DB-API 2.0 interface for SQLite databases. (n.d.). Python Documentation. Retrieved October 4, 2024, from https://docs.python.org/3/library/sqlite3.html
#
# [2] Pyplot tutorial — Matplotlib 2.0.2 documentation. (n.d.). Matplotlib.org. Retrieved October 4, 2024, from https://matplotlib.org/2.0.2/users/pyplot_tutorial.html
